# %%
import pandas as pd
from sportsref.baseball import Season
import numpy as np
#ploting libs
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
szn2021 = Season(2021)

# %%
szn2021.overview()
# you can grab the table from the link below instead of using my sportsref library
# Out:
# Available tables: ['teams_standard_batting', 'teams_standard_pitching', 'team_output', 'teams_standard_fielding']
# < Page, web_url : 'https://www.baseball-reference.com/leagues/MLB/2021.shtml' >

# %%
df = szn2021.overview().get_df("team_output")
# Out:
# Available tables: ['teams_standard_batting', 'teams_standard_pitching', 'team_output', 'teams_standard_fielding']

# %%
cols_to_keep  = ["SP", "RP", "C", "1B", "2B", "3B", "SS","LF","CF","RF","DH"]

# %%
df
# Out:
#     Rk    Total    All P       SP       RP    Non-P        C       1B  \
# 0    1   TOR4.1   CLE3.7   MIL3.3   TOR2.6   BOS3.4   ARI1.3   LAD1.1
# 1    2   SDP4.1   TOR2.8   SFG3.2   CLE2.4   CHW3.4   SFG1.0   HOU0.9
# 2    3   CHW3.9   MIL2.6   LAD2.7   MIA1.1   MIN3.0   MIL1.0   TOR0.8
# 3    4   BOS3.7   PHI2.5   PHI2.4   BAL0.9   TBR2.7   NYY0.7   KCR0.8
# 4    5   HOU3.3   NYY2.3   HOU2.2   NYY0.8   SDP2.6   TBR0.7   CHC0.7
# 5    6   LAD3.0   MIA2.0   DET1.8   SDP0.8   HOU2.4   PIT0.4   CHW0.5
# 6    7   SFG2.8   SDP1.5   NYY1.5   CHC0.6   LAD2.4   WSN0.4   SDP0.4
# 7    8   STL1.1   BAL1.0   NYM1.4   PHI0.3   SFG2.3   KCR0.4   NYM0.4
# 8    9   CLE1.1   HOU0.9   CHW1.4   OAK0.1   WSN2.0   CHC0.3   OAK0.3
# 9   10   TBR0.9   LAA0.7   MIA1.3   PIT0.1   STL1.9   PHI0.3   COL0.3
# 10  11   WSN0.5   OAK0.7   CLE1.2   LAA0.1   TOR1.3   CIN0.3   MIA0.2
# 11  12   NYY0.5   LAD0.6   SDP1.0  KCR-0.1   CHC0.9   STL0.2   TEX0.0
# 12  13   MIA0.5   CHW0.5   OAK0.7  CIN-0.4   COL0.8   CHW0.2  WSN-0.1
# 13  14   OAK0.4   SFG0.5   BOS0.7  TEX-0.4   ARI0.6   LAD0.1  TBR-0.1
# 14  15   MIL0.4   NYM0.5   LAA0.6  STL-0.5  TEX-0.1   SDP0.0  SFG-0.1
# 15  16   PHI0.3   BOS0.3   TEX0.6  BOS-0.5  OAK-0.3   BOS0.0  PHI-0.1
# 16  17   BAL0.2   CIN0.1   CIN0.3  ATL-0.6  BAL-0.8  OAK-0.1  MIN-0.2
# 17  18   TEX0.0   TEX0.1   TOR0.3  SEA-0.7  SEA-0.9  TOR-0.2  LAA-0.3
# 18  19  NYM-0.6   ATL0.0   ATL0.2  MIL-0.8  NYM-1.1  DET-0.3  STL-0.3
# 19  20  CHC-0.9  PIT-0.3   COL0.1  WSN-0.9  CIN-1.4  BAL-0.3  PIT-0.4
# 20  21  CIN-1.3  STL-0.8   BAL0.1  NYM-1.0  KCR-1.4  TEX-0.5  ATL-0.4
# 21  22  COL-1.6  KCR-1.0  TBR-0.2  CHW-1.1  MIA-1.5  MIN-0.5  BAL-0.5
# 22  23  ATL-2.4  DET-1.5  PIT-0.4  HOU-1.3  NYY-1.8  CLE-0.5  ARI-0.5
# 23  24  KCR-2.4  WSN-1.5  STL-0.4  TBR-1.5  MIL-2.2  HOU-0.6  CIN-0.8
# 24  25  LAA-2.9  TBR-1.8  ARI-0.5  LAD-1.8  PHI-2.2  ATL-0.7  BOS-0.9
# 25  26  PIT-3.2  CHC-1.8  WSN-0.7  SFG-2.4  ATL-2.4  NYM-0.7  NYY-1.1
# 26  27  SEA-3.2  SEA-2.3  KCR-0.8  COL-2.5  CLE-2.6  COL-0.7  SEA-1.1
# 27  28  ARI-3.6  COL-2.4  SEA-1.5  DET-3.3  PIT-2.9  SEA-0.8  CLE-1.1
# 28  29  MIN-3.6  ARI-4.2  CHC-2.2  ARI-3.7  LAA-3.6  LAA-1.1  MIL-1.3
# 29  30  DET-6.1  MIN-6.6  MIN-2.3  MIN-4.2  DET-4.6  MIA-1.3  DET-1.3
#
#          2B       3B       SS       LF       CF       RF OF (All)       DH  \
# 0    COL0.9   CLE1.3   TEX1.9   OAK0.5   MIN2.2   CIN1.4   BAL1.6   BOS1.3
# 1    KCR0.8   STL1.2   WSN1.4   COL0.5   LAA1.5   ATL0.8   CIN1.4   CHW0.7
# 2    MIN0.7   BOS1.1   BOS1.3   TBR0.4   BAL1.4   TBR0.6   MIN1.4   HOU0.7
# 3    TOR0.6   CHW0.8   TOR1.1   STL0.4   SDP1.0   SFG0.6   STL1.2   LAA0.5
# 4    TEX0.6   ARI0.7   SFG1.0   DET0.4   OAK0.8   SEA0.5   OAK1.2   NYY0.4
# 5    SDP0.6   MIN0.7   CHW1.0   CIN0.4   LAD0.8   PHI0.5   TBR1.1   MIN0.4
# 6    PHI0.5   TBR0.6   MIA0.8   ARI0.3   STL0.7   HOU0.5   LAD1.0   CLE0.1
# 7    ATL0.3   SEA0.6   SEA0.7   HOU0.3   MIA0.6   BOS0.4   SFG0.7   MIL0.0
# 8    BOS0.3   COL0.5   CHC0.7   BAL0.3   CHW0.5   NYY0.3   SDP0.7   WSN0.0
# 9    HOU0.2   HOU0.5   HOU0.6   PIT0.2   SFG0.4   CHW0.2   BOS0.4   TOR0.0
# 10   WSN0.2   NYY0.3   MIN0.6   LAD0.0   CHC0.3   WSN0.2   CHW0.3   STL0.0
# 11   NYM0.2   NYM0.3   SDP0.5   MIA0.0   KCR0.2   LAD0.2   LAA0.2   SFG0.0
# 12   LAD0.1   SDP0.3   TBR0.4  KCR-0.1   COL0.2   SDP0.1   MIA0.1   SDP0.0
# 13   PIT0.1   CHC0.3   LAD0.3  MIL-0.1   BOS0.2   STL0.1   HOU0.1   PHI0.0
# 14   SEA0.1   DET0.2   NYY0.2  CHC-0.2   TBR0.1   TEX0.1   COL0.1   NYM0.0
# 15   MIA0.0   OAK0.1   BAL0.2  WSN-0.2   TOR0.0   MIL0.0   WSN0.0   ARI0.0
# 16   TBR0.0   WSN0.1   STL0.1  NYM-0.2   WSN0.0   TOR0.0  ARI-0.1   MIA0.0
# 17   STL0.0   ATL0.1  COL-0.1  BOS-0.2  NYM-0.1  OAK-0.1  SEA-0.1   LAD0.0
# 18  MIL-0.1   LAD0.1  CLE-0.2  SFG-0.3  SEA-0.2  BAL-0.1  CHC-0.2   COL0.0
# 19  NYY-0.1  SFG-0.1  ARI-0.3  CHW-0.4  PIT-0.2  ARI-0.1  MIL-0.4   CIN0.0
# 20  SFG-0.1  TOR-0.2  DET-0.4  SEA-0.4  MIL-0.3  LAA-0.2  PHI-0.4  PIT-0.1
# 21  CHW-0.2  TEX-0.4  NYM-0.4  SDP-0.4  ARI-0.3  NYM-0.3  ATL-0.5  SEA-0.1
# 22  OAK-0.3  MIL-0.5  MIL-0.5  PHI-0.4  CLE-0.4  CHC-0.3  NYM-0.6  TBR-0.1
# 23  ARI-0.3  CIN-0.5  KCR-0.5  MIN-0.4  CIN-0.4  MIN-0.4  TOR-0.7  CHC-0.1
# 24  CIN-0.4  BAL-0.5  PIT-0.7  TEX-0.5  PHI-0.5  CLE-0.4  KCR-0.8  ATL-0.1
# 25  BAL-0.5  PIT-0.6  ATL-0.8  CLE-0.5  TEX-0.5  MIA-0.5  PIT-0.9  OAK-0.2
# 26  CLE-0.5  MIA-0.6  PHI-0.9  ATL-0.6  HOU-0.7  DET-0.5  TEX-0.9  TEX-0.4
# 27  CHC-0.6  LAA-0.7  LAA-1.1  TOR-0.7  ATL-0.7  COL-0.6  DET-1.0  KCR-0.5
# 28  DET-0.8  PHI-1.3  OAK-1.2  LAA-1.1  NYY-0.8  PIT-0.9  CLE-1.3  BAL-0.7
# 29  LAA-0.8  KCR-1.5  CIN-1.2  NYY-1.4  DET-0.9  KCR-0.9  NYY-1.9  DET-0.8
#
#          PH
# 0    TBR0.1
# 1    SDP0.1
# 2    CHW0.1
# 3    HOU0.0
# 4    WSN0.0
# 5   BOS-0.1
# 6   KCR-0.1
# 7   SFG-0.1
# 8   TOR-0.1
# 9   MIN-0.1
# 10  BAL-0.1
# 11  OAK-0.1
# 12  CHC-0.2
# 13  CIN-0.2
# 14  COL-0.2
# 15  DET-0.2
# 16  SEA-0.2
# 17  ARI-0.2
# 18  LAD-0.3
# 19  PHI-0.3
# 20  NYY-0.3
# 21  NYM-0.3
# 22  LAA-0.3
# 23  ATL-0.3
# 24  TEX-0.4
# 25  MIL-0.4
# 26  CLE-0.4
# 27  STL-0.5
# 28  PIT-0.7
# 29  MIA-0.7

# %%
pos_df = df[cols_to_keep]

# %%
def split_col(col):
    return [col.str.slice(0,3), col.str.slice(3)]

# %%
def melt_war_table(df,cols):
    dfs = []
    for pos in cols:
        col_team, col_val = split_col(df[pos])
        temp_df = pd.DataFrame({'team' : col_team, 'war': col_val})
        temp_df['position'] = pos
        temp_df['war'] = pd.to_numeric(temp_df['war'])
        dfs.append(temp_df)
    return pd.concat(dfs, ignore_index=True)

# %%
melted_df = melt_war_table(df,cols_to_keep)
melted_df
# Out:
#     team  war position
# 0    MIL  3.3       SP
# 1    SFG  3.2       SP
# 2    LAD  2.7       SP
# 3    PHI  2.4       SP
# 4    HOU  2.2       SP
# ..   ...  ...      ...
# 325  OAK -0.2       DH
# 326  TEX -0.4       DH
# 327  KCR -0.5       DH
# 328  BAL -0.7       DH
# 329  DET -0.8       DH
#
# [330 rows x 3 columns]

# %%
plot_df = melted_df.pivot(index='team', columns='position', values='war').reindex(columns=cols_to_keep)
plot_df
# Out:
# position   SP   RP    C   1B   2B   3B   SS   LF   CF   RF   DH
# team
# ARI      -0.5 -3.7  1.3 -0.5 -0.3  0.7 -0.3  0.3 -0.3 -0.1  0.0
# ATL       0.2 -0.6 -0.7 -0.4  0.3  0.1 -0.8 -0.6 -0.7  0.8 -0.1
# BAL       0.1  0.9 -0.3 -0.5 -0.5 -0.5  0.2  0.3  1.4 -0.1 -0.7
# BOS       0.7 -0.5  0.0 -0.9  0.3  1.1  1.3 -0.2  0.2  0.4  1.3
# CHC      -2.2  0.6  0.3  0.7 -0.6  0.3  0.7 -0.2  0.3 -0.3 -0.1
# CHW       1.4 -1.1  0.2  0.5 -0.2  0.8  1.0 -0.4  0.5  0.2  0.7
# CIN       0.3 -0.4  0.3 -0.8 -0.4 -0.5 -1.2  0.4 -0.4  1.4  0.0
# CLE       1.2  2.4 -0.5 -1.1 -0.5  1.3 -0.2 -0.5 -0.4 -0.4  0.1
# COL       0.1 -2.5 -0.7  0.3  0.9  0.5 -0.1  0.5  0.2 -0.6  0.0
# DET       1.8 -3.3 -0.3 -1.3 -0.8  0.2 -0.4  0.4 -0.9 -0.5 -0.8
# HOU       2.2 -1.3 -0.6  0.9  0.2  0.5  0.6  0.3 -0.7  0.5  0.7
# KCR      -0.8 -0.1  0.4  0.8  0.8 -1.5 -0.5 -0.1  0.2 -0.9 -0.5
# LAA       0.6  0.1 -1.1 -0.3 -0.8 -0.7 -1.1 -1.1  1.5 -0.2  0.5
# LAD       2.7 -1.8  0.1  1.1  0.1  0.1  0.3  0.0  0.8  0.2  0.0
# MIA       1.3  1.1 -1.3  0.2  0.0 -0.6  0.8  0.0  0.6 -0.5  0.0
# MIL       3.3 -0.8  1.0 -1.3 -0.1 -0.5 -0.5 -0.1 -0.3  0.0  0.0
# MIN      -2.3 -4.2 -0.5 -0.2  0.7  0.7  0.6 -0.4  2.2 -0.4  0.4
# NYM       1.4 -1.0 -0.7  0.4  0.2  0.3 -0.4 -0.2 -0.1 -0.3  0.0
# NYY       1.5  0.8  0.7 -1.1 -0.1  0.3  0.2 -1.4 -0.8  0.3  0.4
# OAK       0.7  0.1 -0.1  0.3 -0.3  0.1 -1.2  0.5  0.8 -0.1 -0.2
# PHI       2.4  0.3  0.3 -0.1  0.5 -1.3 -0.9 -0.4 -0.5  0.5  0.0
# PIT      -0.4  0.1  0.4 -0.4  0.1 -0.6 -0.7  0.2 -0.2 -0.9 -0.1
# SDP       1.0  0.8  0.0  0.4  0.6  0.3  0.5 -0.4  1.0  0.1  0.0
# SEA      -1.5 -0.7 -0.8 -1.1  0.1  0.6  0.7 -0.4 -0.2  0.5 -0.1
# SFG       3.2 -2.4  1.0 -0.1 -0.1 -0.1  1.0 -0.3  0.4  0.6  0.0
# STL      -0.4 -0.5  0.2 -0.3  0.0  1.2  0.1  0.4  0.7  0.1  0.0
# TBR      -0.2 -1.5  0.7 -0.1  0.0  0.6  0.4  0.4  0.1  0.6 -0.1
# TEX       0.6 -0.4 -0.5  0.0  0.6 -0.4  1.9 -0.5 -0.5  0.1 -0.4
# TOR       0.3  2.6 -0.2  0.8  0.6 -0.2  1.1 -0.7  0.0  0.0  0.0
# WSN      -0.7 -0.9  0.4 -0.1  0.2  0.1  1.4 -0.2  0.0  0.2  0.0

# %%
plt.xkcd()

# %%
# let's plot
fig, ax = plt.subplots(figsize=(16,15))
im = ax.imshow(plot_df, cmap="bwr_r",
               vmin=-3,vmax=3,
              aspect='auto')

#colorbar
# cmap = mpl.cm.bwr
# norm = mpl.colors.Normalize(vmin=-3,vmax=3)
cbar = ax.figure.colorbar(im,
                          ax=ax, extend='both')
#axes
ax.set_xticks(np.arange(len(plot_df.columns)))
ax.set_yticks(np.arange(len(plot_df.index)))
ax.tick_params(
    top=True,
    labeltop=True)
# labels
ax.set_xticklabels(plot_df.columns, size=20)
ax.set_yticklabels(plot_df.index, size=20)

#loop over data dimentions and create text annotations
for i in range(len(plot_df.columns)):
    for j in range(len(plot_df.index)):
        text = ax.text(i,j,'{0:2g}'.format(plot_df.iloc[j,i]),
                      ha="center", va="center", color="k", size=15)
        

# ax.set_aspect('auto')        
ax.set_title("WAA(b) from position", size=30, pad=20)
# sign
plt.text(-1,31,'u/double_dose_larry', size=12)
plt.tight_layout()
plt.savefig('waa_pos_heatmap.png')
